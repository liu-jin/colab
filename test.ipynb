# %% [markdown]
# <a href="https://colab.research.google.com/github/liu-jin/colab/blob/main/test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
a = 1
print(a+2)
# Out:
# 3

# %%
a = 3

# %% [markdown]
# ceshi yixia

# %%
print(a+3)
# Out:
# 4
